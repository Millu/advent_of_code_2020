# %% [markdown]
# # Day 6
# https://adventofcode.com/2020/day/6

# %%
def read_parse_file(path):
    answers = []
    with open(path) as f:
        answers = f.read().split('\n\n')
        combined_answers = [a.strip().replace('\n', '') for a in answers]
        line_separated_answers = [a.strip().split('\n') for a in answers]
    return combined_answers, line_separated_answers

# %%
def count_yes_answers(answers):
    count = 0
    for a in answers:
        count = count + len(set(a))
    return count

# %%
def count_uniform_yes(answers):
    count = 0 
    for a in answers:
        set_list = []
        for i in a:
            set_list.append(set(i))
        print(set_list)
        print(set().intersection(set), len(set().intersection(*set_list)))
        
    return count

# %%
path = 'input.txt'
answers, separated_answers = read_parse_file(path)

# %%
count_yes_answers(answers)
# Out:
# 6565

# %%
count_uniform_yes(separated_answers)
# Out:
# [{'q', 'r', 'i', 'l', 'j', 't', 'x', 'b', 'e', 'n', 'd', 'g', 'u'}, {'k', 'r', 'n', 'l', 'm', 'j', 't', 'u', 'x', 'e', 'i', 'd', 'q'}, {'v', 'r', 'i', 'c', 't', 'z', 'x', 'h', 'p', 'e', 'n', 'd', 's', 'u'}, {'q', 'r', 'n', 't', 'x', 'e', 'i', 'd', 'y', 'u', 'w'}]
# {'v', 'r', 'j', 'c', 'z', 'u', 'b', 'h', 'p', 'e', 's', 'y', 'k', 'n', 'l', 'm', 't', 'x', 'i', 'd', 'g', 'q', 'w'} 0
# [{'v', 'k', 'l', 'j', 'z', 't', 'h', 'e', 'n'}, {'v', 'k', 'l', 'z', 't', 'h', 'e', 'n', 'w'}, {'v', 'k', 't', 'z', 'b', 'p', 'h', 'e', 'n', 'g'}]
# {'v', 'j', 'z', 'h', 'b', 'p', 'e', 'k', 'l', 't', 'n', 'g', 'w'} 0
# [{'d', 'q'}, {'d'}, {'d'}, {'d'}]
# {'d', 'q'} 0
# ...
